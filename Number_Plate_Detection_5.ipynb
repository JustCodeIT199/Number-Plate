# %% [markdown]
# <a href="https://colab.research.google.com/github/JustCodeIT199/Number-Plate/blob/main/Number_Plate_Detection_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# !pip install opencv-python
from ultralytics import YOLO
import cv2
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 37.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 102.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 83.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 47.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 93.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import matplotlib.pyplot as plt

# %%
model = YOLO('yolov8l.pt')
results = model('/content/drive/MyDrive/project SEM 5 /sample images/y1.jpeg')


plt.imshow(results[0].plot())
plt.show()

# %%
model = YOLO('yolov8l.pt')
results = model('/content/drive/MyDrive/project SEM 5 /sample images/y2.jpeg')


plt.imshow(results[0].plot())
plt.show()

# %%
model = YOLO('yolov8l.pt')
results = model('/content/drive/MyDrive/project SEM 5 /sample images/y3.jpeg')


plt.imshow(results[0].plot())
plt.show()

# %%
import cv2
import torch
from ultralytics import YOLO
from google.colab.patches import cv2_imshow

# YOLOv8 model
model = YOLO('/content/drive/MyDrive/project SEM 5 /yolov8l.pt')

#  object
cap = cv2.VideoCapture('/content/drive/MyDrive/project SEM 5 /sample images/y3.jpeg')

# frames
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break


    results = model(frame)

    #  results
    for result in results[0].boxes.data.cpu().numpy():
        x1, y1, x2, y2, confidence, class_id = result[:6]
        class_name = model.names[int(class_id)]

        if class_name == 'license_plate':
            #  OCR
            cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (255, 0, 0), 2)
            license_plate_text = apply_ocr(frame[int(y1):int(y2), int(x1):int(x2)])
            cv2.putText(frame, license_plate_text, (int(x1), int(y1) - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (255, 0, 0), 2)
        elif class_name == 'helmet':
            cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 2)
        elif class_name == 'person':
            cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 0, 255), 2)


    cv2_imshow(frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break


cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# GRAY SCALING USING OPENCV

# %%
# !pip install easyocr
# !pip install imutils

# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np
import imutils
import easyocr

# %%
img = cv2.imread('/content/drive/MyDrive/project SEM 5 /sample images/14.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(cv2.cvtColor(gray, cv2.COLOR_BGR2RGB))

# %%
bfilter = cv2.bilateralFilter(gray, 11, 17, 17) #Noise reduction
edged = cv2.Canny(bfilter, 30, 200) #Edge detection
plt.imshow(cv2.cvtColor(edged, cv2.COLOR_BGR2RGB))

# %%
keypoints = cv2.findContours(edged.copy(), cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
contours = imutils.grab_contours(keypoints)
contours = sorted(contours, key=cv2.contourArea, reverse=True)[:10]

# %%
location = None
for contour in contours:
    approx = cv2.approxPolyDP(contour, 10, True)
    if len(approx) == 4:
        location = approx
        break

# %%
location

# %%
mask = np.zeros(gray.shape, np.uint8)
new_image = cv2.drawContours(mask, [location], 0,255, -1)
new_image = cv2.bitwise_and(img, img, mask=mask)

# %%
plt.imshow(cv2.cvtColor(new_image, cv2.COLOR_BGR2RGB))

# %%
(x,y) = np.where(mask==255)
(x1, y1) = (np.min(x), np.min(y))
(x2, y2) = (np.max(x), np.max(y))
cropped_image = gray[x1:x2+1, y1:y2+1]

# %%
plt.imshow(cv2.cvtColor(cropped_image, cv2.COLOR_BGR2RGB))

# %%
reader = easyocr.Reader(['en'])
result = reader.readtext(cropped_image)
result

# %%
text = result[0][-2]
font = cv2.FONT_HERSHEY_SIMPLEX
res = cv2.putText(img, text=text, org=(approx[0][0][0], approx[1][0][1]+60), fontFace=font, fontScale=1, color=(0,255,0), thickness=2, lineType=cv2.LINE_AA)
res = cv2.rectangle(img, tuple(approx[0][0]), tuple(approx[2][0]), (0,255,0),3)
plt.imshow(cv2.cvtColor(res, cv2.COLOR_BGR2RGB))

# %% [markdown]
# ##training of helmet and vehicle registration plate

# %%
ROOT_DIR ='/content/drive/MyDrive/project SEM 5 /data2'

# %%
# !pip install ultralytics

# %%
 import os

 from ultralytics import YOLO


# # Load a model
model = YOLO("yolov8n.yaml")  # build a new model from scratch

# Use the model
results = model.train(data=os.path.join(ROOT_DIR, "config.yaml"), epochs=100)  # train the model

# %%
#!zip -r runs.zip runs

# %%
from ultralytics import YOLO

# Load your trained model
model = YOLO('/content/drive/MyDrive/runs/detect/train2/weights/best.pt')

# Validate the model
results = model.val(data='/content/drive/MyDrive/val/config.yaml')

# Print results
print(results)

# %%
cd /content/drive/MyDrive/project SEM 5 /projrct 4

# %% [markdown]
# <!--  -->

# %%
# !pip install -r requirements.txt

# %%
# !python predictWithOCR.py model='/content/drive/MyDrive/project SEM 5 /projrct 4/best.pt' source='/content/drive/MyDrive/project SEM 5 /projrct 4/demo.mp4'
